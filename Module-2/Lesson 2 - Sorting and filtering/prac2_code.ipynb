# %%
import pandas as pd

# %%
df = pd.read_csv('survey_data.csv')
df.head()
# Out:
#     Age  Gender  NumberOfChildren        CountryOfResidence LanguageAtHome  \
# 0  28.0    male               NaN  United States of America        English
# 1  22.0    male               NaN  United States of America        English
# 2  19.0    male               NaN  United States of America        English
# 3  26.0  female               NaN  United States of America        English
# 4  20.0  female               NaN  United States of America          Khmer
#
#    HoursSpentLearningToCode   Income  StudentDebtOwe  IsSoftwareDev  \
# 0                      30.0  32000.0         20000.0          False
# 1                      30.0  15000.0             NaN          False
# 2                      20.0  48000.0             NaN          False
# 3                      20.0  43000.0          7000.0          False
# 4                      25.0   6000.0             NaN          False
#
#                      MaritalStatus  MoneySpentLearningToCode  \
# 0  married or domestic partnership                       0.0
# 1                              NaN                      20.0
# 2                              NaN                      50.0
# 3                              NaN                     100.0
# 4                              NaN                    1300.0
#
#    MonthsSpentProgramming YearsSpentLearningToCode  LearningViaBooks  \
# 0                     1.0            0.08333333333               NaN
# 1                     2.0             0.1666666667               NaN
# 2                    24.0                        2               NaN
# 3                     3.0                     0.25               NaN
# 4                    48.0                        4               NaN
#
#    LearningViaCoursera
# 0                  1.0
# 1                  1.0
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df_sorted_by_age = df.sort_values(by='Age', ascending=False)
df_sorted_by_age.head()
# Out:
#        Age  Gender  NumberOfChildren        CountryOfResidence LanguageAtHome  \
# 5554  86.0    male               NaN                 Australia        English
# 560   80.0    male               NaN              South Africa        English
# 1846  75.0  female               NaN  United States of America        English
# 3927  75.0    male               NaN  United States of America        English
# 450   75.0  female               NaN  United States of America        English
#
#       HoursSpentLearningToCode    Income  StudentDebtOwe  IsSoftwareDev  \
# 5554                       NaN       NaN             NaN           True
# 560                       10.0       NaN             NaN          False
# 1846                       6.0       NaN             NaN          False
# 3927                       NaN  125000.0             NaN           True
# 450                        3.0   50000.0             NaN          False
#
#      MaritalStatus  MoneySpentLearningToCode  MonthsSpentProgramming  \
# 5554           NaN                       NaN                     NaN
# 560            NaN                       0.0                     1.0
# 1846           NaN                       NaN                     3.0
# 3927           NaN                       NaN                     NaN
# 450            NaN                       0.0                     0.0
#
#      YearsSpentLearningToCode  LearningViaBooks  LearningViaCoursera
# 5554                  #VALUE!               NaN                  NaN
# 560             0.08333333333               NaN                  NaN
# 1846                     0.25               NaN                  NaN
# 3927                  #VALUE!               NaN                  NaN
# 450                         0               NaN                  NaN

# %%
columns = ['Age', 'HoursSpentLearningToCode']
order = [False, False]

# %%
sorted_by_age_and_hours = df.sort_values(by=columns, ascending=order)

# %%
unique_genders = pd.unique(df['Gender'])
unique_genders
# Out:
# array(['male', 'female', nan, 'genderqueer', 'trans', 'agender'],
#       dtype=object)

# %%
female_respondents = df[df['Gender'] == 'female']
female_respondents
# Out:
#         Age  Gender  NumberOfChildren        CountryOfResidence  \
# 3      26.0  female               NaN  United States of America
# 4      20.0  female               NaN  United States of America
# 14     31.0  female               NaN                    Russia
# 15     27.0  female               NaN  United States of America
# 19     25.0  female               NaN  United States of America
# ...     ...     ...               ...                       ...
# 15584  24.0  female               1.0                   Ukraine
# 15585  32.0  female               1.0                   Ukraine
# 15587  42.0  female               3.0  United States of America
# 15592  29.0  female               1.0  United States of America
# 15603  48.0  female               2.0  United States of America
#
#       LanguageAtHome  HoursSpentLearningToCode    Income  StudentDebtOwe  \
# 3            English                      20.0   43000.0          7000.0
# 4              Khmer                      25.0    6000.0             NaN
# 14           Russian                      10.0       NaN             NaN
# 15           English                       4.0   80000.0             NaN
# 19             Hindi                       NaN       NaN             NaN
# ...              ...                       ...       ...             ...
# 15584        Russian                      14.0   60000.0             NaN
# 15585        Russian                       5.0   36000.0             NaN
# 15587        English                      20.0   23796.0             NaN
# 15592        English                       2.0  200000.0         40000.0
# 15603        English                      10.0  200000.0         12000.0
#
#        IsSoftwareDev                    MaritalStatus  \
# 3              False                              NaN
# 4              False                              NaN
# 14              True                              NaN
# 15              True                              NaN
# 19              True                              NaN
# ...              ...                              ...
# 15584          False  married or domestic partnership
# 15585          False  married or domestic partnership
# 15587           True  married or domestic partnership
# 15592           True  married or domestic partnership
# 15603           True  married or domestic partnership
#
#        MoneySpentLearningToCode  MonthsSpentProgramming  \
# 3                         100.0                     3.0
# 4                        1300.0                    48.0
# 14                          NaN                   108.0
# 15                        600.0                    36.0
# 19                          NaN                     NaN
# ...                         ...                     ...
# 15584                     150.0                     1.0
# 15585                       5.0                     2.0
# 15587                     750.0                    30.0
# 15592                     500.0                    24.0
# 15603                     500.0                    15.0
#
#       YearsSpentLearningToCode  LearningViaBooks  LearningViaCoursera
# 3                         0.25               NaN                  NaN
# 4                            4               NaN                  NaN
# 14                           9               NaN                  1.0
# 15                           3               NaN                  1.0
# 19                     #VALUE!               NaN                  1.0
# ...                        ...               ...                  ...
# 15584            0.08333333333               NaN                  1.0
# 15585             0.1666666667               NaN                  NaN
# 15587                      2.5               NaN                  NaN
# 15592                        2               NaN                  NaN
# 15603                     1.25               NaN                  NaN
#
# [2840 rows x 15 columns]

# %%
female_respondents['Age'].hist()
# Out:
# <Axes: >

# %%
df[df['HoursSpentLearningToCode'] > 30]
# Out:
#         Age  Gender  NumberOfChildren        CountryOfResidence  \
# 44     19.0    male               NaN                Bangladesh
# 48     35.0  female               NaN  United States of America
# 49     30.0    male               NaN  United States of America
# 66     32.0    male               NaN                   Germany
# 76     38.0  female               NaN  United States of America
# ...     ...     ...               ...                       ...
# 15547  43.0    male               1.0  United States of America
# 15567  36.0    male               1.0        Republic of Serbia
# 15571  61.0    male               2.0  United States of America
# 15607  36.0    male               1.0            United Kingdom
# 15618  37.0    male               1.0                    Canada
#
#       LanguageAtHome  HoursSpentLearningToCode    Income  StudentDebtOwe  \
# 44           Bengali                      56.0       NaN             NaN
# 48           English                      35.0       NaN          5000.0
# 49           English                      40.0       NaN             NaN
# 66           English                      40.0       NaN         30000.0
# 76           English                      40.0       NaN          8000.0
# ...              ...                       ...       ...             ...
# 15547        English                      40.0    6000.0         50000.0
# 15567        Serbian                      35.0   62400.0             NaN
# 15571        English                      40.0   60000.0             NaN
# 15607        English                      69.0  200000.0             NaN
# 15618        English                      40.0  200000.0             NaN
#
#        IsSoftwareDev                    MaritalStatus  \
# 44             False                              NaN
# 48             False            single, never married
# 49             False                              NaN
# 66             False                              NaN
# 76             False                              NaN
# ...              ...                              ...
# 15547           True            single, never married
# 15567          False  married or domestic partnership
# 15571          False  married or domestic partnership
# 15607           True  married or domestic partnership
# 15618          False  married or domestic partnership
#
#        MoneySpentLearningToCode  MonthsSpentProgramming  \
# 44                          0.0                     1.0
# 48                         50.0                   100.0
# 49                       3000.0                     8.0
# 66                        100.0                     2.0
# 76                        200.0                    36.0
# ...                         ...                     ...
# 15547                     500.0                    36.0
# 15567                    5000.0                     4.0
# 15571                     500.0                   240.0
# 15607                       0.0                   360.0
# 15618                     200.0                   360.0
#
#       YearsSpentLearningToCode  LearningViaBooks  LearningViaCoursera
# 44               0.08333333333               NaN                  NaN
# 48                 8.333333333               NaN                  NaN
# 49                0.6666666667               NaN                  NaN
# 66                0.1666666667               NaN                  NaN
# 76                           3               NaN                  NaN
# ...                        ...               ...                  ...
# 15547                        3               NaN                  NaN
# 15567             0.3333333333               NaN                  NaN
# 15571                       20               NaN                  NaN
# 15607                       30               NaN                  NaN
# 15618                       30               NaN                  1.0
#
# [1561 rows x 15 columns]

# %%
female_above_30 = df[(df['Gender'] == 'female') & (df['Age'] >= 30)]
female_above_30
# Out:
#         Age  Gender  NumberOfChildren        CountryOfResidence  \
# 14     31.0  female               NaN                    Russia
# 21     44.0  female               NaN  United States of America
# 30     33.0  female               NaN  United States of America
# 48     35.0  female               NaN  United States of America
# 53     34.0  female               NaN  United States of America
# ...     ...     ...               ...                       ...
# 15556  56.0  female               3.0            United Kingdom
# 15578  42.0  female               6.0  United States of America
# 15585  32.0  female               1.0                   Ukraine
# 15587  42.0  female               3.0  United States of America
# 15603  48.0  female               2.0  United States of America
#
#       LanguageAtHome  HoursSpentLearningToCode    Income  StudentDebtOwe  \
# 14           Russian                      10.0       NaN             NaN
# 21           English                      30.0   41000.0         50000.0
# 30           English                      15.0   40000.0         44000.0
# 48           English                      35.0       NaN          5000.0
# 53           English                       2.0   62500.0         75000.0
# ...              ...                       ...       ...             ...
# 15556        English                      15.0   48000.0             NaN
# 15578        English                      25.0   60000.0          6500.0
# 15585        Russian                       5.0   36000.0             NaN
# 15587        English                      20.0   23796.0             NaN
# 15603        English                      10.0  200000.0         12000.0
#
#        IsSoftwareDev                    MaritalStatus  \
# 14              True                              NaN
# 21             False  married or domestic partnership
# 30             False                              NaN
# 48             False            single, never married
# 53             False                              NaN
# ...              ...                              ...
# 15556          False  married or domestic partnership
# 15578          False  married or domestic partnership
# 15585          False  married or domestic partnership
# 15587           True  married or domestic partnership
# 15603           True  married or domestic partnership
#
#        MoneySpentLearningToCode  MonthsSpentProgramming  \
# 14                          NaN                   108.0
# 21                         75.0                     2.0
# 30                         20.0                     2.0
# 48                         50.0                   100.0
# 53                        250.0                     3.0
# ...                         ...                     ...
# 15556                    2000.0                    11.0
# 15578                       0.0                     0.0
# 15585                       5.0                     2.0
# 15587                     750.0                    30.0
# 15603                     500.0                    15.0
#
#       YearsSpentLearningToCode  LearningViaBooks  LearningViaCoursera
# 14                           9               NaN                  1.0
# 21                0.1666666667               NaN                  NaN
# 30                0.1666666667               NaN                  NaN
# 48                 8.333333333               NaN                  NaN
# 53                        0.25               NaN                  NaN
# ...                        ...               ...                  ...
# 15556             0.9166666667               NaN                  1.0
# 15578                        0               NaN                  NaN
# 15585             0.1666666667               NaN                  NaN
# 15587                      2.5               NaN                  NaN
# 15603                     1.25               NaN                  NaN
#
# [1248 rows x 15 columns]
