# %%
import pandas as pd
df = pd.read_csv('loan_data.csv')

# %%
df.head()
# Out:
#                           emp_title  emp_length state homeownership  \
# 0          administrative assistant           0    FL          RENT
# 1                   sole proprietor          10    MN           OWN
# 2                  pension ananlyst          10    MD           OWN
# 3  director of corporate operations           0    MN      MORTGAGE
# 4                        dispatcher           3    TX          RENT
#
#    debt_to_income  annual_income  open_credit_lines  total_credit_limit  \
# 0           22.51        32000.0                  4               22984
# 1            2.99        45000.0                  5              203255
# 2           21.07        90000.0                 19              154848
# 3           12.28       130000.0                 23              296496
# 4           28.97        65000.0                 28              156207
#
#    total_credit_utilized  total_debit_limit  loan_amount  interest_rate  \
# 0                  18420               5000         2500           7.96
# 1                   1469               9000        12500           7.34
# 2                  62112              79300        13000           7.35
# 3                  77944              93600        17500           7.35
# 4                  70381              50800         8000           7.96
#
#    installment grade   balance  paid_interest
# 0        78.30     A   2326.16          31.65
# 1       387.91     A  11559.92         218.55
# 2       403.49     A  11360.72         364.90
# 3       349.42     A  16273.90         470.99
# 4       250.55     A   7403.61         151.72

# %%
# Visualize loan grades
# Assigned grades A - G
print(pd.unique(df['grade']))
# Out:
# ['A' 'B' 'C' 'D' 'E' 'F' 'G']

# %%
df['grade'].value_counts().plot(kind='bar') # usefulness can be improved
# Out:
# <Axes: xlabel='grade'>

# %%
sorted_grades = df['grade'].value_counts().sort_index()

# %%
sorted_grades.plot(kind='bar')
# Out:
# <Axes: xlabel='grade'>

# %%
# enhance chart using matplotlib
import matplotlib.pyplot as plt

# %%
sorted_grades.plot(kind='bar')
plt.title('Frequency of Loan by Grade')
plt.xlabel('') # empty string removes x label
plt.ylabel('Frequency')
plt.show()

# %%
# improve readability of your chart
sorted_grades.plot(kind='bar', color='purple')
plt.title('Frequency of Loan by Grade')
plt.xlabel('') # empty string removes x label
plt.ylabel('Frequency')
plt.show()

# %%
colors = ['Green', 'Lime', 'Yellow', 'Gold', 'Orange', 'Tomato', 'Red']

# %%
sorted_grades.plot(kind='bar', color=colors)
plt.title('Frequency of Loan by Grade')
plt.xlabel('') # empty string removes x label
plt.ylabel('Frequency')
plt.grid(axis='y', color='black', alpha=0.7, linestyle='--') # default for axis: "both"
plt.show()

# %%
sorted_grades.plot(kind='bar', color=colors)
plt.title('Frequency of Loan by Grade')
plt.xlabel('') # empty string removes x label
plt.ylabel('Frequency')
plt.grid(axis='y', color='black', alpha=0.7, linestyle='--') # default for axis: "both"
plt.savefig('loan_column_chart1.png')

# %%
from matplotlib.ticker import AutoMinorLocator

ax = sorted_grades.plot(kind='bar', color=colors)

# Add value labels on top of each bar
for i, value in enumerate(sorted_grades):
    ax.text(i, value + 1, str(value), ha='center', fontsize=10)

plt.title('Frequency of Loan by Grade', fontsize=16, fontweight='bold', pad=15)
plt.xlabel('')
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', which='both', color='black', alpha=0.4, linestyle='--')
plt.annotate(
    text='Loans Grade E and below \nare very high risk.',
    xy=(4, 50),
    xytext=(-10, 30),
    textcoords='offset points',
    arrowprops=dict(facecolor='black', arrowstyle='->')
)

plt.tight_layout()  # Prevents label cutoff
plt.xticks(rotation=0)

# add additional ticks to your axis
ax.yaxis.set_minor_locator(AutoMinorLocator(2)) # here's where I want those minor axis ticks to be!

# plt.savefig('loan_column_chart_with_annotation.png')
plt.show()

# %%
ax = sorted_grades.plot(kind='bar', color=colors)

# Add value labels on top of each bar
for i, value in enumerate(sorted_grades):
    ax.text(i, value + 1, str(value), ha='center', fontsize=10)

plt.title('Frequency of Loan by Grade', fontsize=16, fontweight='bold', pad=15)
plt.xlabel('')
plt.ylabel('')
plt.annotate(
    text='Loans Grade E and below \nare very high risk.',
    xy=(4, 50),
    xytext=(-10, 30),
    textcoords='offset points',
    arrowprops=dict(facecolor='black', arrowstyle='->')
)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.yaxis.set_ticks([])

plt.xticks(rotation=0)
plt.show()

# %%
states = ['DC','AK','HI']

# %%
filtered_df = df[df['state'].isin(states)]
filtered_df
# Out:
#                    emp_title  emp_length state homeownership  debt_to_income  \
# 44                management          10    DC      MORTGAGE            4.36
# 104             risk manager           3    AK      MORTGAGE           42.52
# 244                  manager           9    AK           OWN           12.31
# 440    mechanic shop foreman          10    AK           OWN           20.85
# 508    project administrator           3    HI          RENT            8.87
# 601                   forman           4    AK          RENT           15.27
# 861                princioal          10    HI          RENT           10.35
# 862          daycare teacher           2    AK      MORTGAGE           24.19
# 1083              admin asst           2    HI           OWN           17.01
# 1166                   owner          10    DC          RENT           23.41
# 1237  journeyman electrician          10    AK      MORTGAGE           15.82
# 1242               recruiter          10    AK      MORTGAGE           30.75
# 1273                 manager           9    HI      MORTGAGE            6.71
# 1490              management           5    DC          RENT           34.91
# 1761  bilingual case manager           2    DC           OWN           24.03
# 1966        vp of operations           2    DC      MORTGAGE           17.42
# 2374              manager/hr           8    AK      MORTGAGE           27.04
# 2421   night shift associate           4    AK          RENT           20.68
# 2591          branch manager           2    AK          RENT           20.84
# 2664      jewelry consultant           1    HI          RENT           12.43
# 2895          police officer          10    HI      MORTGAGE           30.10
# 2926      store brand leader           2    HI          RENT           19.14
# 2943        sales consultant          10    HI          RENT           28.33
# 2980                   nurse          10    HI          RENT           27.81
#
#       annual_income  open_credit_lines  total_credit_limit  \
# 44         152000.0                  6              560826
# 104         89000.0                 14              414662
# 244         35000.0                 19              421180
# 440         80000.0                  5               64718
# 508         75200.0                  9               66906
# 601         90000.0                  5               80384
# 861        130000.0                  9               89368
# 862         21000.0                 10               25300
# 1083        65000.0                 18              111400
# 1166        80000.0                  5               75955
# 1237        95000.0                  7              247114
# 1242        78000.0                 14              443959
# 1273        80400.0                 14              382190
# 1490       187000.0                 22              330513
# 1761        95000.0                 11              122000
# 1966       135000.0                  8              372772
# 2374        51000.0                  8              288077
# 2421        22800.0                  3               11500
# 2591        80000.0                 11               79838
# 2664        50000.0                  7               27776
# 2895        88000.0                  6              106451
# 2926        75000.0                 16               82000
# 2943        90000.0                 13               90551
# 2980        50840.0                  7               57060
#
#       total_credit_utilized  total_debit_limit  loan_amount  interest_rate  \
# 44                    17408              65300        40000           7.34
# 104                  160925              84400        30000           7.35
# 244                    8701             113300        19000           6.71
# 440                   22276               5500        18000           6.71
# 508                   16146              43600         1200           6.72
# 601                   53209              32500        36000           6.71
# 861                   44198              35500         8000          10.42
# 862                   17819              21500        24000          10.42
# 1083                  42813              62200        18000          10.42
# 1166                  27358              26700        15000          11.99
# 1237                  36901              19300        30000          10.41
# 1242                  73454              50700        38500          11.99
# 1273                  15229              45000        27200           9.43
# 1490                 212441              91500        10000          11.98
# 1761                  44762              70600        35000          12.62
# 1966                 101338              26100        16800          16.02
# 2374                  66779              28800        15000          15.05
# 2421                   8130               3500        10000          15.04
# 2591                  54586              15300        11100          21.85
# 2664                  18753               2600        10000          18.06
# 2895                  88611              10800        30000          26.77
# 2926                  65999              25000        30000          23.88
# 2943                  73989              63250        35000          25.81
# 2980                  39314              15500        28000          28.72
#
#       installment grade   balance  paid_interest
# 44         798.49     A  38328.35         707.51
# 104        931.13     A  26217.04         848.19
# 244        584.15     A  17558.24         303.61
# 440        553.41     A  16634.11         301.05
# 508         36.90     A   1078.26          25.41
# 601       1106.81     A  33268.25         561.84
# 861        259.72     B    371.17         117.06
# 862        779.16     B  21096.21         957.28
# 1083       386.18     B      0.00         676.84
# 1166       498.15     B  11551.20         523.82
# 1237       973.81     B  27840.70         727.43
# 1242      1278.57     B  34870.48        1574.52
# 1273       870.41     B  25214.49         611.47
# 1490       332.05     B   9533.25         184.04
# 1761      1172.90     C  30890.38        1730.34
# 1966       408.73     C  16047.29         867.26
# 2374       357.25     C  14486.24         545.45
# 2421       346.85     C   9327.09         359.28
# 2591       305.63     D      0.00         461.32
# 2664       254.27     D      0.00         475.63
# 2895       911.95     E  29255.54        1946.77
# 2926       860.96     E  28912.22        2276.46
# 2943      1043.99     E  34107.48        2139.08
# 2980       884.01     F  27113.29        2604.65

# %%
grouped_df = filtered_df.groupby(['state', 'grade'])
grouped_df

# %%
grouped_loan_amount = grouped_df['loan_amount'].mean()
grouped_loan_amount
# Out:
# state  grade
# AK     A        25750.000000
#        B        30833.333333
#        C        12500.000000
#        D        11100.000000
# DC     A        40000.000000
#        B        12500.000000
#        C        25900.000000
# HI     A         1200.000000
#        B        17733.333333
#        D        10000.000000
#        E        31666.666667
#        F        28000.000000
# Name: loan_amount, dtype: float64

# %%
grouped_loan_amount.plot(kind='bar')
# Out:
# <Axes: xlabel='state,grade'>

# %%
# unstack grades into columns
grouped_loan_amount.unstack()
# Out:
# grade        A             B        C        D             E        F
# state
# AK     25750.0  30833.333333  12500.0  11100.0           NaN      NaN
# DC     40000.0  12500.000000  25900.0      NaN           NaN      NaN
# HI      1200.0  17733.333333      NaN  10000.0  31666.666667  28000.0

# %%
grouped_loan_amount.unstack().plot(kind='bar')
plt.show()

# %%
ax = grouped_loan_amount.unstack().plot(kind='bar', color=colors)
plt.title('Average Loan Amount, Top Three States', fontsize=16, pad=15)
plt.xlabel('State',fontsize=14)
plt.ylabel('Average Loan Amount ($)', fontsize=14)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', color='black', alpha=0.4)
plt.legend(title='Grade', bbox_to_anchor=(1,1))
plt.show()
plt.savefig('grouped_by_state_and_grade.png')
